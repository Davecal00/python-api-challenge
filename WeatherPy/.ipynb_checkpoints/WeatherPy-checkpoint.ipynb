# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
url = f"{url}units=metric&"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
counter = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"] 

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
    # Wait for 1 minute and 10 seconds after every 59th record
    counter += 1
    if counter == 59:
        time.sleep(70)
        counter = 0
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | koslan
# Processing Record 11 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | klaksvik
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | saint-pierre
# Processing Record 17 of Set 1 | komsomolskiy
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | san cristobal
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | mangrol
# Processing Record 22 of Set 1 | santa cruz del sur
# Processing Record 23 of Set 1 | touros
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | eureka
# Processing Record 26 of Set 1 | muros
# Processing Record 27 of Set 1 | constitucion
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | anadyr
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | codrington
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | suntar
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | puerto carreno
# Processing Record 39 of Set 1 | boissevain
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | kaeo
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | bo rai
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | sisimiut
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | kahului
# Processing Record 0 of Set 2 | manggar
# Processing Record 1 of Set 2 | esperance
# Processing Record 2 of Set 2 | kushmurun
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | mitsamiouli
# Processing Record 5 of Set 2 | valdivia
# Processing Record 6 of Set 2 | tullow
# Processing Record 7 of Set 2 | amahai
# Processing Record 8 of Set 2 | tres lagoas
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | vardo
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | caravelas
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | soyo
# Processing Record 19 of Set 2 | awbari
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | wairoa
# Processing Record 22 of Set 2 | scarborough
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | abha
# Processing Record 25 of Set 2 | abu samrah
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | la rioja
# Processing Record 28 of Set 2 | provideniya
of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | selma
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | rawson
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | cayenne
# Processing Record 14 of Set 4 | biasong
# Processing Record 15 of Set 4 | kozhva
# Processing Record 16 of Set 4 | araouane
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | los llanos de aridane
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | rognan
# Processing Record 21 of Set 4 | zheleznodorozhnyy
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | berlin
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | kosino
# Processing Record 27 of Set 4 | puerto ayora
# Processing Record 28 of Set 4 | olinda
# Processing Record 29 of Set 4 | sibolga
# Processing Record 30 of Set 4 | coihaique
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | saskylakh
# Processing Record 33 of Set 4 | wajid
# Processing Record 34 of Set 4 | veraval
# Processing Record 35 of Set 4 | killybegs
# Processing Record 36 of Set 4 | payson
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | henties bay
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | yellowknife
# Processing Record 41 of Set 4 | bosaso
# Processing Record 42 of Set 4 | sai buri
# Processing Record 43 of Set 4 | preili
# Processing Record 44 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 4 | takestan
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | baijiantan
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | ozerna
# Processing Record 0 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 5 | moindou
# Processing Record 2 of Set 5 | kawalu
# Processing Record 3 of Set 5 | tuktoyaktuk
# Processing Record 4 of Set 5 | tagusao
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | lagoa
# Processing Record 7 of Set 5 | kargasok
# Processing Record 8 of Set 5 | nouadhibou
# Processing Record 9 of Set 5 | puri
# Processing Record 10 of Set 5 | mollendo
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | hosur
# Processing Record 13 of Set 5 | togur
# Processing Record 14 of Set 5 | ambilobe
# Processing Record 15 of Set 5 | matagami
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | kovur
# Processing Record 18 of Set 5 | bhatkal
# Processing Record 19 of Set 5 | moanda
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | nuuk
# Processing Record 22 of Set 5 | si chiang mai
# Processing Record 23 of Set 5 | nelson bay
# Processing Record 24 of Set 5 | sidi bu zayd
# City not found. Skipping...
# Processing Record 25 of Set 5 | thunder bay
# Processing Record 26 of Set 5 | coro
# Processing Record 27 of Set 5 | rongcheng
# Processing Record 28 of Set 5 | asind
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | college
# Processing Record 31 of Set 5 | bilma
# Processing Record 32 of Set 5 | belmonte
# Processing Record 33 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 34 of Set 5 | sobolevo
# Processing Record 35 of Set 5 | goderich
# Processing Record 36 of Set 5 | havre-saint-pierre
# Processing Record 37 of Set 5 | fidenza
# Processing Record 38 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 5 | arlit
# Processing Record 40 of Set 5 | avarua
# Processing Record 41 of Set 5 | chino valley
# Processing Record 42 of Set 5 | jabinyanah
# Processing Record 43 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 44 of Set 5 | stornoway
# Processing Record 45 of Set 5 | tabuk
# Processing Record 46 of Set 5 | shakiso
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | yarada
# Processing Record 49 of Set 5 | mae hong son
# Processing Record 0 of Set 6 | domoni
# Processing Record 1 of Set 6 | dikson
# Processing Record 2 of Set 6 | okhotsk
# Processing Record 3 of Set 6 | lufilufi
# Processing Record 4 of Set 6 | antofagasta
# Processing Record 5 of Set 6 | sinnamary
# Processing Record 6 of Set 6 | guanajuato
# Processing Record 7 of Set 6 | invermere
# Processing Record 8 of Set 6 | san carlos de bariloche
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | rock sound
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | nyurba
# Processing Record 14 of Set 6 | batagay
# Processing Record 15 of Set 6 | gorgan
# Processing Record 16 of Set 6 | moree
# Processing Record 17 of Set 6 | santa isabel do rio negro
# Processing Record 18 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | hithadhoo
# Processing Record 20 of Set 6 | ler
# Processing Record 21 of Set 6 | egvekinot
# Processing Record 22 of Set 6 | sabha
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | turayf
# Processing Record 25 of Set 6 | praia da vitoria
# Processing Record 26 of Set 6 | beloha
# Processing Record 27 of Set 6 | baturite
# Processing Record 28 of Set 6 | jasper
# Processing Record 29 of Set 6 | paamiut
# Processing Record 30 of Set 6 | rockhampton
# Processing Record 31 of Set 6 | yerbogachen
# Processing Record 32 of Set 6 | kanigoro
# Processing Record 33 of Set 6 | eyrarbakki
# Processing Record 34 of Set 6 | clyde river
# Processing Record 35 of Set 6 | walvis bay
# Processing Record 36 of Set 6 | oktyabrskiy
# Processing Record 37 of Set 6 | almaznyy
# Processing Record 38 of Set 6 | copiapo
# Processing Record 39 of Set 6 | mogadishu
# Processing Record 40 of Set 6 | abashiri
# Processing Record 41 of Set 6 | yenangyaung
# Processing Record 42 of Set 6 | wasilla
# Processing Record 43 of Set 6 | huaidian
# Processing Record 44 of Set 6 | dingle
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | zhigansk
# Processing Record 47 of Set 6 | bilecik
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | paralimni
# Processing Record 0 of Set 7 | cervo
# Processing Record 1 of Set 7 | bairiki
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | nouakchott
# Processing Record 4 of Set 7 | marsa matruh
# Processing Record 5 of Set 7 | paris
# Processing Record 6 of Set 7 | shellbrook
# Processing Record 7 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 7 | hauzenberg
# Processing Record 9 of Set 7 | istria
# Processing Record 10 of Set 7 | sergeyevka
# Processing Record 11 of Set 7 | esmeraldas
# Processing Record 12 of Set 7 | srednekolymsk
# Processing Record 13 of Set 7 | bima
# Processing Record 14 of Set 7 | suzun
# Processing Record 15 of Set 7 | bijie
# Processing Record 16 of Set 7 | luanda
# Processing Record 17 of Set 7 | kardla
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | hollola
# Processing Record 20 of Set 7 | pontal do parana
# Processing Record 21 of Set 7 | hobyo
# Processing Record 22 of Set 7 | mayahi
# Processing Record 23 of Set 7 | fare
# Processing Record 24 of Set 7 | carolina
# Processing Record 25 of Set 7 | jalu
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | vila velha
# Processing Record 28 of Set 7 | pocatello
# Processing Record 29 of Set 7 | severomuysk
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | san quintin
# Processing Record 32 of Set 7 | villa guerrero
# Processing Record 33 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 7 | junagarh
# Processing Record 35 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 7 | marapanim
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | alexandria
# Processing Record 39 of Set 7 | kant
# Processing Record 40 of Set 7 | nyagan
# Processing Record 41 of Set 7 | faya
# Processing Record 42 of Set 7 | verkh-usugli
# Processing Record 43 of Set 7 | shimoda
# Processing Record 44 of Set 7 | banff
# Processing Record 45 of Set 7 | quartucciu
# Processing Record 46 of Set 7 | aksarka
# Processing Record 47 of Set 7 | porterville
# Processing Record 48 of Set 7 | oga
# Processing Record 49 of Set 7 | tiksi
# Processing Record 0 of Set 8 | terra santa
# Processing Record 1 of Set 8 | mount isa
# Processing Record 2 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | suyan
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | high prairie
# Processing Record 7 of Set 8 | senador jose porfirio
# Processing Record 8 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 8 | utinga
# Processing Record 10 of Set 8 | mataram
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | namatanai
# Processing Record 13 of Set 8 | sovetskaya gavan
# Processing Record 14 of Set 8 | racalmuto
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | ostrovnoy
# Processing Record 17 of Set 8 | erenhot
# Processing Record 18 of Set 8 | daru
# Processing Record 19 of Set 8 | enid
# Processing Record 42 of Set 9 | waspan
# Processing Record 43 of Set 9 | the valley
# Processing Record 44 of Set 9 | zhoucheng
# Processing Record 45 of Set 9 | irbil
# Processing Record 46 of Set 9 | vostok
# Processing Record 47 of Set 9 | shingu
# Processing Record 48 of Set 9 | radstadt
# Processing Record 49 of Set 9 | viedma
# Processing Record 0 of Set 10 | tynda
# Processing Record 1 of Set 10 | auckland
# Processing Record 2 of Set 10 | kailua
# Processing Record 3 of Set 10 | puerto penasco
# Processing Record 4 of Set 10 | santa fe
# Processing Record 5 of Set 10 | chunskiy
# Processing Record 6 of Set 10 | sorland
# Processing Record 7 of Set 10 | sao joao de pirabas
# Processing Record 8 of Set 10 | kalanguy
# Processing Record 9 of Set 10 | mishan
# Processing Record 10 of Set 10 | yatou
# Processing Record 11 of Set 10 | alihe
# Processing Record 12 of Set 10 | colares
# Processing Record 13 of Set 10 | general roca
# Processing Record 14 of Set 10 | boali
# Processing Record 15 of Set 10 | lazaro cardenas
# Processing Record 16 of Set 10 | savinka
# Processing Record 17 of Set 10 | kharan
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | port blair
# Processing Record 20 of Set 10 | moen
# Processing Record 21 of Set 10 | nantucket
# Processing Record 22 of Set 10 | manta
# Processing Record 23 of Set 10 | liberia
# Processing Record 24 of Set 10 | whitehorse
# Processing Record 25 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 10 | ridgecrest
# Processing Record 27 of Set 10 | meerbusch
# Processing Record 28 of Set 10 | mahon
# Processing Record 29 of Set 10 | klofta
# Processing Record 30 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 10 | bonthe
# Processing Record 32 of Set 10 | bose
# Processing Record 33 of Set 10 | kango
# Processing Record 34 of Set 10 | diego de almagro
# Processing Record 35 of Set 10 | simplicio mendes
# Processing Record 36 of Set 10 | waraseoni
# Processing Record 37 of Set 10 | half moon bay
# Processing Record 38 of Set 10 | chulman
# Processing Record 39 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 10 | stolberg
# Processing Record 41 of Set 10 | santa eulalia
# Processing Record 42 of Set 10 | lompoc
# Processing Record 43 of Set 10 | tuy hoa
# Processing Record 44 of Set 10 | mackay
# Processing Record 45 of Set 10 | yuncheng
# Processing Record 46 of Set 10 | fonte boa
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 10 | atambua
# Processing Record 0 of Set 11 | butembo
# Processing Record 1 of Set 11 | ginir
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | pimentel
# Processing Record 5 of Set 11 | swansea
# Processing Record 6 of Set 11 | clinton
# Processing Record 7 of Set 11 | homer
# Processing Record 8 of Set 11 | bantou
# Processing Record 9 of Set 11 | harper
# Processing Record 10 of Set 11 | qaqortoq
# Processing Record 11 of Set 11 | gorlice
# Processing Record 12 of Set 11 | axim
# Processing Record 13 of Set 11 | port moresby
# Processing Record 14 of Set 11 | bato
# Processing Record 15 of Set 11 | marondera
# Processing Record 16 of Set 11 | narsaq
# Processing Record 17 of Set 11 | uribia
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 11 | olafsvik
# Processing Record 21 of Set 11 | trinidad
# Processing Record 22 of Set 11 | sur
# Processing Record 23 of Set 11 | manitouwadge
# Processing Record 24 of Set 11 | ardee
# Processing Record 25 of Set 11 | ixtapa
# Processing Record 26 of Set 11 | pochutla
# Processing Record 27 of Set 11 | nova olimpia
# Processing Record 28 of Set 11 | karymskoye
# Processing Record 29 of Set 11 | elkridge
# Processing Record 30 of Set 11 | shache
# Processing Record 31 of Set 11 | onguday
# Processing Record 32 of Set 11 | magadan
# Processing Record 33 of Set 11 | gushikawa
# Processing Record 34 of Set 11 | ulladulla
# Processing Record 35 of Set 11 | hovd
# Processing Record 36 of Set 11 | mahibadhoo
# Processing Record 37 of Set 11 | luba
# Processing Record 38 of Set 11 | powell
# Processing Record 39 of Set 11 | kuala terengganu
# Processing Record 40 of Set 11 | batemans bay
# Processing Record 41 of Set 11 | tateyama
# Processing Record 42 of Set 11 | tabora
# Processing Record 43 of Set 11 | twin falls
# Processing Record 44 of Set 11 | rio pomba
# Processing Record 45 of Set 11 | canyon
# Processing Record 46 of Set 11 | tottori
# Processing Record 47 of Set 11 | choya
# Processing Record 48 of Set 11 | aksu
# Processing Record 49 of Set 11 | lilongwe
# Processing Record 0 of Set 12 | devils lake
# Processing Record 1 of Set 12 | guapo
# Processing Record 2 of Set 12 | namtsy
# Processing Record 3 of Set 12 | lomas de sargentillo
# Processing Record 4 of Set 12 | rafaela
# Processing Record 5 of Set 12 | ust-nera
# Processing Record 6 of Set 12 | arroio grande
# Processing Record 7 of Set 12 | teya
# Processing Record 8 of Set 12 | umm kaddadah
# Processing Record 9 of Set 12 | yantarnyy
# Processing Record 10 of Set 12 | puerto del rosario
# Processing Record 11 of Set 12 | villa maria
# Processing Record 12 of Set 12 | necochea
# Processing Record 13 of Set 12 | portlethen
# Processing Record 14 of Set 12 | gemena
# Processing Record 15 of Set 12 | midleton
# Processing Record 16 of Set 12 | sitka
# Processing Record 17 of Set 12 | otjiwarongo
# Processing Record 18 of Set 12 | kushima
# Processing Record 19 of Set 12 | paso de carrasco
# Processing Record 20 of Set 12 | seymchan
# Processing Record 21 of Set 12 | prince rupert
# Processing Record 22 of Set 12 | disna
# Processing Record 23 of Set 12 | moussoro
# Processing Record 24 of Set 12 | oistins
# Processing Record 25 of Set 12 | wanning
# Processing Record 26 of Set 12 | pueblo
# Processing Record 27 of Set 12 | aripuana
# Processing Record 28 of Set 12 | ntungamo
# Processing Record 29 of Set 12 | agadez
# Processing Record 30 of Set 12 | mayumba
# Processing Record 31 of Set 12 | boyolangu
# Processing Record 32 of Set 12 | benghazi
# Processing Record 33 of Set 12 | nichinan
# Processing Record 34 of Set 12 | sioux falls
# Processing Record 35 of Set 12 | ankang
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | rybinsk
# Processing Record 38 of Set 12 | srivardhan
# Processing Record 39 of Set 12 | ojinaga
# Processing Record 40 of Set 12 | kundiawa
# Processing Record 41 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 12 | namwala
# Processing Record 43 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 44 of Set 12 | huilong
# Processing Record 45 of Set 12 | bressanone
# Processing Record 46 of Set 12 | ormara
# Processing Record 47 of Set 12 | mount pleasant
# Processing Record 48 of Set 12 | reoti
# Processing Record 49 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 0 of Set 13 | belgrade
# Processing Record 1 of Set 13 | soresina
# Processing Record 2 of Set 13 | yanam
# Processing Record 3 of Set 13 | acapulco
# Processing Record 4 of Set 13 | barcelona
# Processing Record 5 of Set 13 | huarmey
# Processing Record 6 of Set 13 | pingzhuang
# Processing Record 7 of Set 13 | maldonado
# Processing Record 8 of Set 13 | geraldton
# Processing Record 9 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 13 | bluefield
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  souillac -20.5167   57.5167     23.21        78          75        6.69
# 1    albany  42.6001  -73.9662     27.24        80          94        0.87
# 2    atuona  -9.8000 -139.0333     25.83        83          49       11.48
# 3   mataura -46.1927  168.8643      7.16        84         100        0.81
# 4    castro -24.7911  -50.0119     14.42        93          75        3.02
#
#   Country        Date
# 0      MU  1688858855
# 1      US  1688858839
# 2      PF  1688858582
# 3      NZ  1688858645
# 4      BR  1688858856

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        souillac -20.5167   57.5167     23.21        78          75
# 1          albany  42.6001  -73.9662     27.24        80          94
# 2          atuona  -9.8000 -139.0333     25.83        83          49
# 3         mataura -46.1927  168.8643      7.16        84         100
# 4          castro -24.7911  -50.0119     14.42        93          75
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      MU  1688858855
# 1              0.87      US  1688858839
# 2             11.48      PF  1688858582
# 3              0.81      NZ  1688858645
# 4              3.02      BR  1688858856

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=.75, marker="o")
plt.title("City Latitude vs. Temperature (03-26-2023)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Incorporate the other graph properties
plt.ylim(-20, 40)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=.75, marker="o")
plt.title("City Latitude vs. Humidity (03-26-2023)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Incorporate the other graph properties
plt.ylim(0, 105)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=.75, marker="o")
plt.title("City Latitude vs. Cloudiness (03-26-2023)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Incorporate the other graph properties
plt.ylim(0, 105)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=.75, marker="o")
plt.title("City Latitude vs. Wind Speed (03-26-2023)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Incorporate the other graph properties
plt.ylim(-.5, 15)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")

    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)

    print(f"The r-value is: {rvalue}")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                albany  42.6001  -73.9662     27.24        80          94
# 5                 pevek  69.7008  170.3133     10.20        60          95
# 7                koslan  63.4564   48.8989     11.29        98         100
# 8        severo-kurilsk  50.6789  156.1250     10.53        92          85
# 10             klaksvik  62.2266   -6.5890     14.51        94          84
#
#          Wind Speed Country        Date
# City_ID
# 1              0.87      US  1688858839
# 5              8.80      RU  1688858856
# 7              2.91      RU  1688858857
# 8              6.00      RU  1688858857
# 10             5.03      FO  1688858840

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        souillac -20.5167   57.5167     23.21        78          75
# 2          atuona  -9.8000 -139.0333     25.83        83          49
# 3         mataura -46.1927  168.8643      7.16        84         100
# 4          castro -24.7911  -50.0119     14.42        93          75
# 6          hobart -42.8794  147.3294      9.92        76          40
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      MU  1688858855
# 2             11.48      PF  1688858582
# 3              0.81      NZ  1688858645
# 4              3.02      BR  1688858856
# 6              7.72      AU  1688858834

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
title = 'Northern Hemisphere - Max Temp vs. Latitude Linear Regression'
y_label = 'Max Temp (C)'

plot_linear_regression(x_values, y_values, title, y_label, (5, -10))
# Out:
# The r-value is: -0.6717950112088776

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
title = 'Southern Hemisphere - Max Temp vs. Latitude Linear Regression'
y_label = 'Max Temp (C)'

plot_linear_regression(x_values, y_values, title, y_label, (-55, 30))
# Out:
# The r-value is: 0.8173764260129417

# %% [markdown]
# **Discussion about the linear relationship:** Max temperature decreases as latitude increases in the Northern Hemisphere, and max temperature increases as latitude increases in the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
title = 'Northern Hemisphere - Humidity vs. Latitude Linear Regression'
y_label = 'Humidity (%)'

plot_linear_regression(x_values, y_values, title, y_label, (40, 10))
# Out:
# The r-value is: -0.04378969333742224

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
title = 'Southern Hemisphere - Humidity vs. Latitude Linear Regression'
y_label = 'Humidity (%)'

plot_linear_regression(x_values, y_values, title, y_label, (-50, 20))
# Out:
# The r-value is: 0.06154470237825403

# %% [markdown]
# **Discussion about the linear relationship:** It seems to be that there is a slight increase in humidty as latitude increases in both Hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
title = 'Northern Hemisphere - Cloudiness vs. Latitude Linear Regression'
y_label = 'Cloudiness (%)'

plot_linear_regression(x_values, y_values, title, y_label, (40, 10))
# Out:
# The r-value is: -0.00880739365774768

# %%
# Sorthern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
title = 'Southern Hemisphere - Cloudiness vs. Latitude Linear Regression'
y_label = 'Cloudiness (%)'

plot_linear_regression(x_values, y_values, title, y_label, (-30, 30))
# Out:
# The r-value is: -0.016346892650711767

# %% [markdown]
# **Discussion about the linear relationship:** It seems to be that there is a slight increase in cloudiness as latitude increases in the Northern Hemisphere, but this much more in the Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
title = 'Northern Hemisphere - Wind Speed vs. Latitude Linear Regression'
y_label = 'Wind Speed (m/s)'

plot_linear_regression(x_values, y_values, title, y_label, (10, 12))
# Out:
# The r-value is: -0.046975084133706144

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
title = 'Southern Hemisphere - Wind Speed vs. Latitude Linear Regression'
y_label = 'Wind Speed (m/s)'

plot_linear_regression(x_values, y_values, title, y_label, (-50, 8))
# Out:
# The r-value is: -0.21075059851500796

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, there seems to be no correlation between wind speed and latitude. In the Southern Hemishpere, it looks like wind speed decreases slightly as latitude increases.
